# %%
import gradio as gr
import os

#print("PORT=", os.getenv("PORT"))
def respond(message, history):
    result = f"You said: {message}\n and I said that I am just learning AI"
    return result


#gr.ChatInterface(fn=respond,  title="My First Space", 
#                description="This is my first space. I am learning AI and this is my first space.").launch(share=True,)   

gr.ChatInterface(fn=respond,  title="My First Space", 
                 description="This is my first space. I am learning AI and this is my first space.").launch(server_name="0.0.0.0", server_port=os.getenv("PORT",9000))
